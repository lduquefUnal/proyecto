# %%
# %pip uninstall qiskit qiskit-terra qiskit-aer qiskit-machine-learning -y

# %pip install qiskit==0.44.2
# %pip install qiskit-aer==0.12.
# %pip install qiskit-machine-learning==0.6.1

# %pip install torch torchvision matplotlib
# Out:
# Found existing installation: qiskit 0.44.2
# Uninstalling qiskit-0.44.2:
#   Successfully uninstalled qiskit-0.44.2
# Found existing installation: qiskit-terra 0.25.2.1
# Uninstalling qiskit-terra-0.25.2.1:
#   Successfully uninstalled qiskit-terra-0.25.2.1
# Found existing installation: qiskit-aer 0.12.2
# Uninstalling qiskit-aer-0.12.2:
#   Successfully uninstalled qiskit-aer-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Skipping qiskit-machine-learning as it is not installed.
# Collecting qiskit==0.44.2
#   Using cached qiskit-0.44.2-py3-none-any.whl (8.2 kB)
# Collecting qiskit-terra==0.25.2.1
#   Using cached qiskit_terra-0.25.2.1-cp38-abi3-win_amd64.whl (5.1 MB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (4.15.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (1.23.5)
# Requirement already satisfied: ply>=3.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (7.1.3)
# Requirement already satisfied: scipy>=1.5 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (1.15.3)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (5.6.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (1.14.0)
# Requirement already satisfied: dill>=0.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.25.2.1->qiskit==0.44.2) (0.3.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.2.1->qiskit==0.44.2) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.3->qiskit-terra==0.25.2.1->qiskit==0.44.2) (1.3.0)
# Installing collected packages: qiskit-terra, qiskit
# Successfully installed qiskit-0.44.2 qiskit-terra-0.25.2.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting qiskit-aer==0.12.
#   Using cached qiskit_aer-0.12.0-cp310-cp310-win_amd64.whl (9.6 MB)
# Requirement already satisfied: scipy>=1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-aer==0.12.) (1.15.3)
# Requirement already satisfied: qiskit-terra>=0.21.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-aer==0.12.) (0.25.2.1)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-aer==0.12.) (1.23.5)
# Requirement already satisfied: psutil>=5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (7.1.3)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (4.15.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (1.14.0)
# Requirement already satisfied: dill>=0.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (0.3.5.1)
# Requirement already satisfied: ply>=3.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (3.11)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra>=0.21.0->qiskit-aer==0.12.) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.21.0->qiskit-aer==0.12.) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.21.0->qiskit-aer==0.12.) (1.3.0)
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.12.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting qiskit-machine-learning==0.6.1
#   Using cached qiskit_machine_learning-0.6.1-py3-none-any.whl (148 kB)
# Requirement already satisfied: qiskit-terra>=0.22.2 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (0.25.2.1)
# Requirement already satisfied: fastdtw in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (0.3.4)
# Requirement already satisfied: dill>=0.3.4 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (0.3.5.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (65.5.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (1.7.2)
# Requirement already satisfied: psutil>=5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-machine-learning==0.6.1) (7.1.3)
# Requirement already satisfied: scipy>=1.4 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (1.15.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-machine-learning==0.6.1) (1.23.5)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (5.6.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (2.9.0.post0)
# Requirement already satisfied: sympy>=1.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (1.14.0)
# Requirement already satisfied: ply>=3.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (3.11)
# Requirement already satisfied: typing-extensions in c:\users\administrador\appdata\roaming\python\python310\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (4.15.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning==0.6.1) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning==0.6.1) (1.5.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.22.2->qiskit-machine-learning==0.6.1) (1.3.0)
# Installing collected packages: qiskit-machine-learning
# Successfully installed qiskit-machine-learning-0.6.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torch in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (2.9.1)
# Requirement already satisfied: torchvision in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (0.24.1)
# Requirement already satisfied: matplotlib in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (3.10.7)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: filelock in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: jinja2 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from torch) (4.15.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: numpy in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pyparsing>=3 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ============================================================
# IMPORTS
# ============================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import matplotlib.pyplot as plt
import numpy as np

# Qiskit (VERSION COMPATIBLE)
from qiskit import QuantumCircuit
from qiskit.primitives import Estimator
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector
from qiskit.circuit import ParameterVector # Necesario para definir inputs y pesos
from qiskit.opflow import Z, I 

# ============================================================
# 1. PREPARAR MNIST REDUCIDO A 4 CARACTERÍSTICAS
# ============================================================

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

mnist_data = datasets.MNIST(root="./data", train=True, transform=transform, download=True)

# Tomamos SOLO 1000 imágenes para no durar horas
subset_indices = list(range(1000))
mnist_small = Subset(mnist_data, subset_indices)

train_loader = DataLoader(mnist_small, batch_size=32, shuffle=True)


# Función para reducir 28x28 -> 4 valores
def reduce_to_4_features(img):
    img = img.view(28, 28)
    return torch.tensor([
        img[:14, :14].mean(),   # cuadrante 1
        img[:14, 14:].mean(),   # cuadrante 2
        img[14:, :14].mean(),   # cuadrante 3
        img[14:, 14:].mean()    # cuadrante 4
    ])


# ============================================================
# 2. CONSTRUIR EL QNN CUÁNTICO (VERSIÓN CORREGIDA FINAL)
# ============================================================


def create_qnn(n_qubits=4):
    qc = QuantumCircuit(n_qubits)
    input_params = ParameterVector('x', n_qubits)
    weight_params = ParameterVector('w', n_qubits)
    
    # [Circuit definition remains the same]
    for i in range(n_qubits):
        qc.rx(input_params[i], i)
        qc.ry(weight_params[i], i)
    for i in range(n_qubits - 1):
        qc.cx(i, i + 1)
        
    # --- Definición de Observables ---
    # Queremos 4 salidas, así que medimos Z en cada qubit por separado.
    # El observable será: [Z_0, Z_1, Z_2, Z_3]
    observables = [Z ^ (I * (n_qubits - 1 - i)) for i in range(n_qubits)]

    estimator = Estimator()

    qnn = EstimatorQNN(
        estimator=estimator,
        circuit=qc,
        input_params=list(input_params),
        weight_params=list(weight_params),
        # *** CORRECCIÓN CLAVE ***:
        # Pasa la lista de 4 observables. Esto garantiza 4 salidas.
        observables=observables 
    )

    return qnn

# ============================================================
# 3. MODELO HÍBRIDO PyTorch + QNN
# ============================================================

class HybridModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(4, 4)

        # La instancia QNN ahora está correctamente configurada
        qnn = create_qnn() 
        self.quantum = TorchConnector(qnn)

        # La salida del QNN por defecto será de tamaño 4 (una expectativa por qubit)
        self.fc_out = nn.Linear(4, 10) 

    def forward(self, x):
        x = x.view(-1, 4)
        x = torch.tanh(self.fc1(x))
        x = self.quantum(x)
        x = self.fc_out(x)
        return F.log_softmax(x, dim=1)

# Inicialización del modelo (debe ejecutarse después de las definiciones)
model = HybridModel()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.NLLLoss()

# ============================================================
# 4. ENTRENAMIENTO
# ============================================================

losses = []

print("\nEntrenando modelo híbrido cuántico...\n")

for epoch in range(5):  # 5 epochs para mostrar rápido
    total_loss = 0

    for images, labels in train_loader:
        feats = torch.stack([reduce_to_4_features(img) for img in images])

        optimizer.zero_grad()
        output = model(feats) # ¡Esto ya no debería fallar!
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    losses.append(total_loss)
    print(f"Epoch {epoch+1}, loss = {total_loss:.4f}")

print("\nEntrenamiento finalizado ✔\n")


# ============================================================
# 5. GRAFICAR CURVA DE PÉRDIDA
# ============================================================

plt.plot(losses)
plt.title("Curva de pérdida - Modelo Cuántico Híbrido")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()


# ============================================================
# 6. PREDICCIÓN DE UNA IMAGEN
# ============================================================

def predict(img):
    x = reduce_to_4_features(img).unsqueeze(0)
    with torch.no_grad():
        pred = model(x)
    return torch.argmax(pred, dim=1).item()


# Tomamos un ejemplo de MNIST
sample_img, sample_label = mnist_data[0]
pred_value = predict(sample_img)

print(f"Etiqueta real: {sample_label}")
print(f"Predicción cuántica: {pred_value}")
# Out:
# Entrenando modelo híbrido cuántico...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 135
#     132 feats = torch.stack([reduce_to_4_features(img) for img in images])
#     134 optimizer.zero_grad()
# --> 135 output = model(feats) # ¡Esto ya no debería fallar!
#     136 loss = criterion(output, labels)
#     137 loss.backward()
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[7], line 112, in HybridModel.forward(self, x)
#     110 x = torch.tanh(self.fc1(x))
#     111 x = self.quantum(x)
# --> 112 x = self.fc_out(x)
#     113 return F.log_softmax(x, dim=1)
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32x1 and 4x10)
